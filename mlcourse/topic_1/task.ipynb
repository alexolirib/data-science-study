# %%
import numpy as np
import pandas as pd

pd.set_option("display.max.columns", 100)
# to draw pictures in jupyter notebook
# %matplotlib inline
# we don't like warnings
# you can comment the following 2 lines if you'd like to
import warnings

import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")

# %%
DATA_URL = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/"

# %%
df = pd.read_csv(DATA_URL + "adult.data.csv")
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.to_csv('adult.data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### 1) How many men and women (sex feature) are represented in this dataset?

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %%
df['sex'].value_counts(normalize=True)
# Out:
# sex
# Male      0.669205
# Female    0.330795
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### 2) What is the average age (age feature) of women?

# %%
df[df['sex'] == 'Female']['age'].mean()
# Out:
# 36.85823043357163

# %% [markdown]
# ### 3) What is the percentage of German citizens (native-country feature)?

# %%
value = df['native-country'].value_counts(normalize=True)['Germany']
# type(value)
print('%{}'.format(value.round(4)))
# Out:
# %0.0042

# %% [markdown]
# ### 4 and 5) What are the mean and standard deviation of age for those who earn more than 50K per year (salary feature) and those who earn less than 50K per year?

# %%
# df[df['salary'] == '>50K'].groupby('salary')['age'].agg([np.std, np.mean])
df.groupby('salary')['age'].agg([np.std, np.mean])
# Out:
#               std       mean
# salary
# <=50K   14.020088  36.783738
# >50K    10.519028  44.249841

# %% [markdown]
# ### 6) Is it true that people who earn more than 50K have at least high school education? (education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters or Doctorate feature)

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
df[df['salary'] == '>50K']
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 32539   71                 ?  287372     Doctorate             16
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 7      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
df[df['salary'] == '>50K']['education'].value_counts()
# False
# Out:
# education
# Bachelors       2221
# HS-grad         1675
# Some-college    1387
# Masters          959
# Prof-school      423
# Assoc-voc        361
# Doctorate        306
# Assoc-acdm       265
# 10th              62
# 11th              60
# 7th-8th           40
# 12th              33
# 9th               27
# 5th-6th           16
# 1st-4th            6
# Name: count, dtype: int64

# %%
pd.crosstab(df['salary'], df['education'])
# Out:
# education  10th  11th  12th  1st-4th  5th-6th  7th-8th  9th  Assoc-acdm  \
# salary
# <=50K       871  1115   400      162      317      606  487         802
# >50K         62    60    33        6       16       40   27         265
#
# education  Assoc-voc  Bachelors  Doctorate  HS-grad  Masters  Preschool  \
# salary
# <=50K           1021       3134        107     8826      764         51
# >50K             361       2221        306     1675      959          0
#
# education  Prof-school  Some-college
# salary
# <=50K              153          5904
# >50K               423          1387

# %% [markdown]
# ### 7) Display age statistics for each race (race feature) and each gender (sex feature). Use groupby() and describe(). Find the maximum age of men of Amer-Indian-Eskimo race.

# %%
df.groupby('age')[['race','sex']].value_counts(normalize=True)
# Out:
# age  race                sex
# 17   White               Male      0.473418
#                          Female    0.410127
#      Black               Male      0.048101
#                          Female    0.037975
#      Other               Female    0.012658
#                                      ...
# 90   White               Male      0.511628
#                          Female    0.279070
#      Asian-Pac-Islander  Male      0.116279
#      Black               Female    0.046512
#                          Male      0.046512
# Name: proportion, Length: 546, dtype: float64

# %%
df.groupby('age')[['race','sex']].describe()
# Out:
#      race                      sex
#     count unique    top freq count unique     top freq
# age
# 17    395      5  White  349   395      2    Male  209
# 18    550      5  White  483   550      2    Male  282
# 19    712      5  White  630   712      2    Male  356
# 20    753      5  White  653   753      2    Male  390
# 21    720      5  White  627   720      2    Male  391
# ..    ...    ...    ...  ...   ...    ...     ...  ...
# 85      3      1  White    3     3      2    Male    2
# 86      1      1  White    1     1      1  Female    1
# 87      1      1  White    1     1      1    Male    1
# 88      3      1  White    3     3      2    Male    2
# 90     43      3  White   34    43      2    Male   29
#
# [73 rows x 8 columns]

# %%
# 2.
# Idade maxima 
df[(df['race'] == 'Amer-Indian-Eskimo') & (df['sex'] == 'Male')]['age'].agg(np.max)
# Out:
# 82

# %% [markdown]
# ### 8. Among whom is the proportion of those who earn a lot (>50K) greater: married or single men (marital-status feature)? Consider as married those who have a marital-status starting with Married (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), the rest are considered bachelors.

# %%
df['normalized-marital-status'] = df['marital-status'].apply(
    lambda x: 'married' if x in ['Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse'] else 'single')

# %%
df[df['salary'] == '>50K']['normalized-marital-status'].value_counts(normalize=True)
# Out:
# normalized-marital-status
# married    0.859074
# single     0.140926
# Name: proportion, dtype: float64

# %% [markdown]
# ### 9. What is the maximum number of hours a person works per week (hours-per-week feature)? How many people work such a number of hours, and what is the percentage of those who earn a lot (>50K) among them?

# %%
# maior horas
df['hours-per-week'].agg(np.max)
# Out:
# 99

# %%
# quantos
df[df['hours-per-week'] == 99].size
# Out:
# 1360

# %%
df[df['hours-per-week'] == 99]['salary'].value_counts(normalize=True)
# Out:
# salary
# <=50K    0.705882
# >50K     0.294118
# Name: proportion, dtype: float64

# %% [markdown]
# ### 10. Count the average time of work (hours-per-week) for those who earn a little and a lot (salary) for each country (native-country). What will these be for Japan?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.groupby(['salary', 'native-country'])['hours-per-week'].agg(np.median)
# Out:
# salary  native-country
# <=50K   ?                  40.0
#         Cambodia           40.0
#         Canada             40.0
#         China              40.0
#         Columbia           40.0
#                            ...
# >50K    Thailand           50.0
#         Trinadad&Tobago    40.0
#         United-States      40.0
#         Vietnam            40.0
#         Yugoslavia         46.0
# Name: hours-per-week, Length: 82, dtype: float64

# %%
pd.crosstab(df['salary'], df['native-country'])
# Out:
# native-country    ?  Cambodia  Canada  China  Columbia  Cuba  \
# salary
# <=50K           437        12      82     55        57    70
# >50K            146         7      39     20         2    25
#
# native-country  Dominican-Republic  Ecuador  El-Salvador  England  France  \
# salary
# <=50K                           68       24           97       60      17
# >50K                             2        4            9       30      12
#
# native-country  Germany  Greece  Guatemala  Haiti  Holand-Netherlands  \
# salary
# <=50K                93      21         61     40                   1
# >50K                 44       8          3      4                   0
#
# native-country  Honduras  Hong  Hungary  India  Iran  Ireland  Italy  Jamaica  \
# salary
# <=50K                 12    14       10     60    25       19     48       71
# >50K                   1     6        3     40    18        5     25       10
#
# ...

# %%
df_agg = pd.pivot_table(
    df,
    values=['hours-per-week'],
    index=['salary', 'native-country'] 
).reset_index()

df_agg.sort_values(['native-country', 'salary']).head(50)
# Out:
#    salary      native-country  hours-per-week
# 0   <=50K                   ?       40.164760
# 42   >50K                   ?       45.547945
# 1   <=50K            Cambodia       41.416667
# 43   >50K            Cambodia       40.000000
# 2   <=50K              Canada       37.914634
# 44   >50K              Canada       45.641026
# 3   <=50K               China       37.381818
# 45   >50K               China       38.900000
# 4   <=50K            Columbia       38.684211
# 46   >50K            Columbia       50.000000
# 5   <=50K                Cuba       37.985714
# 47   >50K                Cuba       42.440000
# 6   <=50K  Dominican-Republic       42.338235
# 48   >50K  Dominican-Republic       47.000000
# 7   <=50K             Ecuador       38.041667
# 49   >50K             Ecuador       48.750000
# 8   <=50K         El-Salvador       36.030928
# 50   >50K         El-Salvador       45.000000
# 9   <=50K             England       40.483333
# ...

# %%
df_agg[df_agg['native-country'] == 'Japan']
# Out:
#    salary native-country  hours-per-week
# 24  <=50K          Japan       41.000000
# 65   >50K          Japan       47.958333
